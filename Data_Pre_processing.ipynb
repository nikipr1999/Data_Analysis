# %% [markdown]
# # Data Preprocessing
# It is the process of converting or mapping data from one “raw” form into another
# format to make it ready for further analysis.

# %% [markdown]
# # it is also called as data wrangling or data cleaning

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Finding the missing value
# if data is not present at some position
# it can be a ?, N/A, NaN, -
#
# In such a case we can remove the record with such a missing value

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # To drop such a row or column with missing values
# use dropna
# dataframe.dropna(subset=["column_name"],axis=0 ,inplace=True)
#
# axis=0 is to remeve the row
#
# axis=1 is to remove the column
#
# inplace= True will make a change directly into the dataframe

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# df.[column_name].replace(np.nan,mean)
